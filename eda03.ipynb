# %%
import pandas as pd
import numpy as np
import os

# %%
results_df1 = pd.read_csv(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + "\\EDA\\2019-Oct_purchase.csv", sep=',', header=0)

# %%
results_df1.head()
# Out:
#    Unnamed: 0           event_time event_type  product_id  \
# 0         162  2019-10-01 00:02:14   purchase     1004856
# 1         308  2019-10-01 00:04:37   purchase     1002532
# 2         379  2019-10-01 00:06:02   purchase     5100816
# 3         442  2019-10-01 00:07:07   purchase    13800054
# 4         574  2019-10-01 00:09:26   purchase     4804055
#
#            category_id                category_code    brand   price  \
# 0  2053013555631882655       electronics.smartphone  samsung  130.76
# 1  2053013555631882655       electronics.smartphone    apple  642.69
# 2  2053013553375346967                          NaN   xiaomi   29.51
# 3  2053013557418656265    furniture.bathroom.toilet  santeri   54.42
# 4  2053013554658804075  electronics.audio.headphone    apple  189.91
#
#      user_id                          user_session  \
# 0  543272936  8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 1  551377651  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# ...

# %%
results_df2 = pd.read_csv(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + "\\EDA\\2019-Nov_purchase.csv", sep=',', header=0)

# %%
results_df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1           event_time event_type  product_id  \
# 0         107           107  2019-11-01 00:00:41   purchase    13200605
# 1         168           168  2019-11-01 00:01:04   purchase     1005161
# 2         707           707  2019-11-01 00:04:51   purchase     1004856
# 3         811           811  2019-11-01 00:05:34   purchase    26401669
# 4         939           939  2019-11-01 00:06:33   purchase     1801881
#
#            category_id           category_code    brand   price    user_id  \
# 0  2053013557192163841   furniture.bedroom.bed      NaN  566.30  559368633
# 1  2053013555631882655  electronics.smartphone   xiaomi  211.92  513351129
# 2  2053013555631882655  electronics.smartphone  samsung  128.42  562958505
# 3  2053013563651392361                     NaN  lucente  109.66  541854711
# 4  2053013554415534427    electronics.video.tv  samsung  488.80  557746614
#
#                            user_session  \
# ...

# %%
results_df = pd.concat([results_df1, results_df2])

# %%
results_df.head()
# Out:
#    Unnamed: 0           event_time event_type  product_id  \
# 0         162  2019-10-01 00:02:14   purchase     1004856
# 1         308  2019-10-01 00:04:37   purchase     1002532
# 2         379  2019-10-01 00:06:02   purchase     5100816
# 3         442  2019-10-01 00:07:07   purchase    13800054
# 4         574  2019-10-01 00:09:26   purchase     4804055
#
#            category_id                category_code    brand   price  \
# 0  2053013555631882655       electronics.smartphone  samsung  130.76
# 1  2053013555631882655       electronics.smartphone    apple  642.69
# 2  2053013553375346967                          NaN   xiaomi   29.51
# 3  2053013557418656265    furniture.bathroom.toilet  santeri   54.42
# 4  2053013554658804075  electronics.audio.headphone    apple  189.91
#
#      user_id                          user_session  \
# 0  543272936  8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 1  551377651  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# ...
